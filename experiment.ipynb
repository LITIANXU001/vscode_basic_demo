# %%
import numpy as np

snr = np.array([0, 5, 10, 15, 20])
snr
# Out:
# array([ 0,  5, 10, 15, 20])

# %%
ber = np.array([0.2, 0.08, 0.02, 0.003, 0.0002])

ber
# Out:
# array([0.2   , 0.08  , 0.02  , 0.003 , 0.0002])

# %%
import matplotlib.pyplot as plt

plt.semilogy(snr, ber, marker="o")
plt.xlabel("SNR (dB)")
plt.ylabel("BER")
plt.grid(True)
plt.show()
